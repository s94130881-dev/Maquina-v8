# %% [markdown]
# # Maquina-v8 — Cloud PC Linux
#
# XFCE + XRDP + Tailscale + detecção de GPU.

# %%
# !nvidia-smi || true
# !uname -a
# !free -h
# !df -h /

# %%
# !rm -rf /content/Maquina-v8
# !git clone https://github.com/s94130881-dev/Maquina-v8.git /content/Maquina-v8
# %cd /content/Maquina-v8
# !chmod +x scripts/*.sh

# %%
# %cd /content/Maquina-v8
# !bash scripts/gpu_check.sh

# %%
# %cd /content/Maquina-v8
# !sudo bash scripts/install.sh
